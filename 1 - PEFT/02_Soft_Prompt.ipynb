# %% [markdown]
# # Homework 1 Part 2
#
# ## Course Name: Large Language Models
# #### Lecturers: Dr. Soleimani, Dr. Rohban, Dr. Asgari
#
# ---
#
# #### Notebooks Supervised By: MohammadAli SadraeiJavaheri
# #### Notebooks Prepared By: Zeinab Sadat Taghavi, Hamed Jamshidian, Seyed Mohammad Reza Modarres
#
# **Contact**: Ask your questions in Quera
#
# ---
#
# ### Instructions:
# - Complete all exercises presented in this notebook.
# - Ensure you run each cell after you've entered your solution.
# - After completing the exercises, save the notebook and <font color='red'>follow the submission guidelines provided in the PDF.</font>
#
#
# ---
#
# **Note**: Replace the placeholders (between `## Your code begins ##` and `## Your code ends ##`) with the appropriate details.

# %% [markdown]
# #### Reihaneh Halvaei

# %% [markdown]
# # Introduction

# %% [markdown]
# <b> What are soft prompts? </b>
# <br>
# soft prompts can be described as a concept that involves incorporating vectors into an input sequence and then fine-tuning these vectors while keeping the rest of the pre-trained model's components unchanged. We deonte our input with $X$ and we denote $P$ as the matrix of these soft prompt vectors.
# <br>
# <div>
# <img src="https://drive.google.com/uc?id=1aGI6FgvK3udOmHnWt1dCvC7lh6e9C2Oe" width="50%"/>
# </div>
#
# Read More :
# <br>[Youtube : PEFT and Soft Prompt](https://www.youtube.com/watch?v=8uy_WII76L0)
# <br>[Blog : What are soft prompts?](https://softwaremind.com/blog/how-and-why-soft-promps-are-slowly-replacing-text-prompts/)

# %% [markdown]
# ### Requirements

# %%
# %%capture
! pip install datasets transformers

# %% [markdown]
# ### Imports

# %%
from tqdm.notebook import tqdm
from IPython import display

import numpy as np
import pandas as pd

from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn

from datasets import load_dataset
from transformers import T5TokenizerFast, T5ForConditionalGeneration, DataCollatorForSeq2Seq

# %% [markdown]
# ### Constants

# %% [markdown]
# ### Base Model Selection
# We will use `t5-small` as our base model from Hugging Face ([HF_Link](https://huggingface.co/t5-small)). For our tuning, we intend to utilize `10` soft prompt tokens ([HF_Link](https://huggingface.co/docs/peft/conceptual_guides/prompting), [Paper_Link](https://arxiv.org/abs/2104.08691)).

# %%
#####################################
###### DO NOT CHANGE THIS CELL ######
#####################################

BASE_MODEL_NAME = 't5-small'
N_SOFT_PROMPT_TOKENS = 10

BATCH_SIZE = 32
LEARNING_RATE = 0.1
EPOCHS = 10

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Dataset

# %% [markdown]
# ### Load dataset

# %% [markdown]
# `imdb` dataset is a famouns NLP for binary sentiment dataset. Each row of data is either `negative` or `positive` ([HF_Link](https://huggingface.co/datasets/imdb)).

# %%
dataset = load_dataset('imdb')
dataset.pop('unsupervised')
print(dataset)
# Out:
# Downloading builder script:   0%|          | 0.00/4.31k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.59k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/84.1M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 25000
#     })
# })

# %% [markdown]
# ### Define related functions

# %% [markdown]
# Because `T5` model is a sequence to sequence model we should map our labels to label_names before training and doing vice versa duing calculating metrics.
#
# The functions `id2label` and `label2id` are defined to do this.

# %%
def id2label(ids):
    label_names = ['negative', 'positive']
    return [label_names[id] for id in ids]

def label2id(labels):
    label_names_dict = {
        'negative': 0,
        'positive': 1
    }
    return [
        label_names_dict.get(label, 2)
        for label in labels
    ]

# %% [markdown]
# # Tokenizer

# %% [markdown]
# ### Load tokenizer

# %%
tokenizer = T5TokenizerFast.from_pretrained(BASE_MODEL_NAME)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]

# %% [markdown]
# ### Process dataset using tokenizer

# %% [markdown]
# In this step we will getting our dataset ready for training.
#
# We preprocess tokenize our `text` and `label`.
#
# For easier prompt tuning we put placeholders by prepending multiple `pad_token` to our input. The count of this pad tokens is the same as `n_soft_prompt_tokens`.
#
# <font color='#73FF73'><b>You have to complete</b></font> `preprend_padding_token` <font color='#73FF73'><b>function.</b></font>
#
# Replace `None` with your code.

# %%
def preprocess_input(text):
    text = text.lower()
    text = text.replace('<br />', ' ')
    return text

def preprend_padding_token(text):
    n_soft_prompt_tokens = N_SOFT_PROMPT_TOKENS
    pad_token = tokenizer.pad_token

    ######### Your code begins #########
    prefix = pad_token * n_soft_prompt_tokens
    ######### Your code ends ###########

    return prefix + text

def map_function(row):
    processed_input = [
        preprend_padding_token(preprocess_input(text))
        for text in row['text']
    ]
    input_info = tokenizer(processed_input, truncation=True, max_length=256)
    output_info = tokenizer(id2label(row['label']))
    return {
        **input_info,
        'labels': output_info.input_ids
    }


dataset = dataset.map(map_function, batched=True)
dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'labels'])
# Out:
# Map:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/25000 [00:00<?, ? examples/s]

# %% [markdown]
# # Model

# %% [markdown]
# ### Load model

# %%
model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %% [markdown]
# ### Define prompt related layers

# %% [markdown]
# In this part we will define our prompt layer in `SimplePrompts`. It's a simple layer that only returns it's prompt matrix when called.
#
# `EmbeddingWrapper` is a layer that will replace original embedding layer of model and it functions as our injection into the model architecture.
#
# We use `sharif_llm` in our PEFT module name so we could keep it unfreeze during training.
#
# <font color='#73FF73'><b>You have to complete</b></font> `prompts_joiner` <font color='#73FF73'><b>function.</b></font>
#
# In this function prompts will concatenated to model input embeddings. But in `preprend_padding_token` we allready put some placeholders for prompts. We just need to replace it with real prompts.
#
# At first step you must repeat `prompts` in each batch_size and then remove placeholder embedings from `input_embedding` to calculate `non_place_holders`.

# %%
class SimplePrompts(nn.Module):
    def __init__(self, inital_values: torch.Tensor):
        super().__init__()
        self.n_tokens = inital_values.size(0)
        self.emb_dim = inital_values.size(1)
        self.prompt_emb = nn.parameter.Parameter(
            inital_values.detach().clone()
        )

    def forward(self):
        return self.prompt_emb

def prompts_joiner(prompts, input_embedding):
    # prompts.shape         = (n_tokens, emb_dim)
    # input_embedding.shape = (batch_size, n_tokens + seq_len, emb_dim)

    n_tokens = prompts.size(0)
    batch_size = input_embedding.size(0)
    ######### Your code begins #########
    prompts_batched = prompts.unsqueeze(0).expand(batch_size, -1, -1)
    non_place_holders = input_embedding[:, n_tokens:, :]
    ######### Your code ends ###########

    assert prompts_batched.shape == (batch_size, *prompts.shape)
    assert non_place_holders.shape[1] + n_tokens == input_embedding.shape[1]

    return torch.cat([prompts_batched, non_place_holders], dim=1)

class EmbeddingWrapper(nn.Module):
    def __init__(
        self,
        emb_layer: nn.Embedding,
        n_tokens: int,
        **kwargs
    ):
        super().__init__()
        self.emb_layer = emb_layer

        prompt_inital_values = self.emb_layer.weight[:n_tokens]

        self.sharif_llm_soft_prompts = SimplePrompts(inital_values=prompt_inital_values)

    def forward(self, tokens):
        prompts = self.sharif_llm_soft_prompts()
        input_embedding = self.emb_layer(tokens)
        return prompts_joiner(prompts, input_embedding)

# %% [markdown]
# ### Replace encoder's embedding layer with our layer

# %% [markdown]
# <font color='#73FF73'><b>You have to complete</b></font> `mutate_model` <font color='#73FF73'><b>function.</b></font>
#
# In this part we want to replace <b>model encoder embedding layer</b> with our wrapper.
#
# You must use `get_encoder`, `get_input_embeddings` to get model embedding layer and use `EmbeddingWrapper` to create new embedding layer.

# %%
def mutate_model(model, n_tokens):
    if hasattr(model, '_mutated'):
        print("Model already contains Soft Prompt layers! \n Try reloading the model.")
        return
    ######### Your code begins #########
    encoder = model.get_encoder()
    embedding_layer = encoder.get_input_embeddings()
    new_embedding_layer = EmbeddingWrapper(embedding_layer, n_tokens)
    ######### Your code ends ###########
    encoder.set_input_embeddings(new_embedding_layer)

    model._mutated = True

mutate_model(model, n_tokens=N_SOFT_PROMPT_TOKENS)

# %% [markdown]
# ### Freeze all model's weight except our PEFT module

# %% [markdown]
# In this part we will freeze entire model except `encoder.embed_tokens.sharif_llm_soft_prompts.prompt_emb`

# %%
def freeze_non_pefts(model, peft_key):
    print('Non freezed weights:')
    for param_name, weights in model.named_parameters():
        weights.requires_grad = peft_key in param_name
        if weights.requires_grad:
            print(param_name)

freeze_non_pefts(model, peft_key='sharif_llm')
# Out:
# Non freezed weights:
# encoder.embed_tokens.sharif_llm_soft_prompts.prompt_emb

# %% [markdown]
# # Train and evaluate

# %% [markdown]
# ### Define dataloaders

# %%
col_fn = DataCollatorForSeq2Seq(
    tokenizer, return_tensors='pt', padding='longest',
)

train_loader = torch.utils.data.DataLoader(
    dataset['train'],
    batch_size=BATCH_SIZE,
    collate_fn=col_fn,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    dataset['test'],
    batch_size=BATCH_SIZE,
    collate_fn=col_fn
)

# %% [markdown]
# ### Train functions

# %%
def train_loop(model, loader, optimizer):
    model.train()

    batch_losses = []

    for row in tqdm(loader, desc='Training:'):
        optimizer.zero_grad()

        out = model(**row.to(model.device))
        loss = out.loss

        batch_loss_value = loss.item()
        loss.backward()
        optimizer.step()

        batch_losses.append(batch_loss_value)

    loss_value = np.mean(batch_losses)
    return {'train_loss': loss_value}

def _predict(model, row):
    return model.generate(
        input_ids=row.input_ids,
        attention_mask=row.attention_mask,
        max_length=5
    )

def tokenizer_ids_to_label(all_input_ids):
    return tokenizer.batch_decode(all_input_ids, skip_special_tokens=True)

def valid_loop(model, loader, compute_metrics):
    model.eval()

    all_true = []
    all_pred = []

    with torch.no_grad():
        for row in tqdm(loader, desc='Validating:'):
            row.to(model.device)
            pred = _predict(model, row)

            all_true += row.labels.detach().cpu().tolist()
            all_pred += pred.detach().cpu().tolist()

    all_true = label2id(tokenizer_ids_to_label(all_true))
    all_pred = label2id(tokenizer_ids_to_label(all_pred))

    return {'valid_acc': compute_metrics(y_true=all_true, y_pred=all_pred)}

# %% [markdown]
# ### Define our optimizer and metric function

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
compute_metrics = accuracy_score

# %%
model.to(DEVICE)

all_results = []
for epoch in range(EPOCHS):
    epoch_results = {'epoch': epoch}

    epoch_results.update(
        train_loop(
            model=model,
            loader=train_loader,
            optimizer=optimizer,
        )
    )

    epoch_results.update(
        valid_loop(
            model=model,
            loader=test_loader,
            compute_metrics=compute_metrics,
        )
    )
    all_results.append(epoch_results)

    display.clear_output()
    display.display(pd.DataFrame(all_results).set_index('epoch'))
# Out:
#        train_loss  valid_acc
# epoch
# 0        1.399650    0.84648
# 1        0.202947    0.84468
# 2        0.195328    0.85440
# 3        0.191030    0.86160
# 4        0.184948    0.86488
# 5        0.189023    0.86472
# 6        0.186221    0.86456
# 7        0.188335    0.85980
# 8        0.186295    0.86160
# 9        0.184185    0.86512

# %% [markdown]
# ### Best Performance and number of parameters

# %% [markdown]
# You must report this number in you final report.

# %%
best_score = pd.DataFrame(all_results)['valid_acc'].max() * 100
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
print('Best model preformance is: %%%.1f' % best_score)
# Out:
# Number of parameters: 60511744
# Best model preformance is: %86.5

# %% [markdown]
# ### Save PEFT file

# %% [markdown]
# We expect you to <font color='#FF7373'>upload this file </font> with the rest of your files.

# %%
peft_dict = {
    key: val
    for (key, val) in model.state_dict().items()
    if 'sharif_llm' in key
}
torch.save(peft_dict, 'prompts.pt')

# %% [markdown]
# # Use external library

# %%
! pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.24.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install git+https://github.com/thunlp/OpenDelta.git
# Out:
# Collecting git+https://github.com/thunlp/OpenDelta.git
#   Cloning https://github.com/thunlp/OpenDelta.git to /tmp/pip-req-build-9eyltkkf
#   Running command git clone --filter=blob:none --quiet https://github.com/thunlp/OpenDelta.git /tmp/pip-req-build-9eyltkkf
#   Resolved https://github.com/thunlp/OpenDelta.git to commit 067eed2304cb1bdfe462094e42a37de4de98edff
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (2.1.0+cu118)
# Requirement already satisfied: transformers>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (4.35.0)
# Requirement already satisfied: datasets>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (2.14.6)
# Collecting sentencepiece>=0.1.96 (from opendelta==0.3.2)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.2 in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (4.66.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (4.4.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (13.6.0)
# Collecting web.py (from opendelta==0.3.2)
#   Downloading web.py-0.62.tar.gz (623 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 623.2/623.2 kB 11.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting gitpython (from opendelta==0.3.2)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (1.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from opendelta==0.3.2) (1.2.2)
# Collecting delta_center_client==0.0.4 (from opendelta==0.3.2)
#   Downloading delta_center_client-0.0.4-py3-none-any.whl (8.5 kB)
# Collecting bigmodelvis (from opendelta==0.3.2)
#   Downloading bigmodelvis-0.0.1-py3-none-any.whl (13 kB)
# Collecting oss2==2.15.0 (from delta_center_client==0.0.4->opendelta==0.3.2)
#   Downloading oss2-2.15.0.tar.gz (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.4/226.4 kB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting yacs>=0.1.6 (from delta_center_client==0.0.4->opendelta==0.3.2)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests!=2.9.0 in /usr/local/lib/python3.10/dist-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2.31.0)
# Collecting crcmod>=1.7 (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome>=3.4.7 (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2)
#   Downloading pycryptodome-3.19.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.6 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2)
#   Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 10.8 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2)
#   Downloading aliyun-python-sdk-core-2.14.0.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.0/443.0 kB 24.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (1.16.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (3.8.6)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (0.17.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=1.17.0->opendelta==0.3.2) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->opendelta==0.3.2) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->opendelta==0.3.2) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->opendelta==0.3.2) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->opendelta==0.3.2) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->opendelta==0.3.2) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->opendelta==0.3.2) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->opendelta==0.3.2) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->opendelta==0.3.2) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->opendelta==0.3.2) (0.4.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython->opendelta==0.3.2)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->opendelta==0.3.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->opendelta==0.3.2) (2.16.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->opendelta==0.3.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->opendelta==0.3.2) (3.2.0)
# Collecting cheroot (from web.py->opendelta==0.3.2)
#   Downloading cheroot-10.0.0-py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=1.17.0->opendelta==0.3.2) (1.3.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->opendelta==0.3.2)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->opendelta==0.3.2) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests!=2.9.0->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests!=2.9.0->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests!=2.9.0->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2023.7.22)
# Requirement already satisfied: more-itertools>=2.6 in /usr/local/lib/python3.10/dist-packages (from cheroot->web.py->opendelta==0.3.2) (10.1.0)
# Collecting jaraco.functools (from cheroot->web.py->opendelta==0.3.2)
#   Downloading jaraco.functools-4.0.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->opendelta==0.3.2) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.17.0->opendelta==0.3.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=1.17.0->opendelta==0.3.2) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->opendelta==0.3.2) (1.3.0)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (41.0.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2==2.15.0->delta_center_client==0.0.4->opendelta==0.3.2) (2.21)
# Building wheels for collected packages: opendelta, oss2, web.py, aliyun-python-sdk-core, crcmod
#   Building wheel for opendelta (setup.py) ... done
#   Created wheel for opendelta: filename=opendelta-0.3.2-py3-none-any.whl size=83198 sha256=7f97bc45c1130d04486a0d86a33f64504ade193acef0bf26af827676e2ae605f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8um732e6/wheels/d9/aa/39/7120d574ade0204d439e834ddd4b1ec3c9dac8713e7b38a97c
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.15.0-py3-none-any.whl size=103428 sha256=7b49792b436a9e30d558c412fd52ccdfafb9ca6e6b711788a87b0ea77f6fd693
#   Stored in directory: /root/.cache/pip/wheels/b0/ba/d0/22bff0a960e1d68da577c7770f1f4bb4f98f925160f3b5c465
#   Building wheel for web.py (pyproject.toml) ... done
#   Created wheel for web.py: filename=web.py-0.62-py3-none-any.whl size=78565 sha256=b0dc6b31b48c97853031538bdecc49f060ad1878ca5f3b98c9bc42eb65f82623
#   Stored in directory: /root/.cache/pip/wheels/66/0a/bf/09f23b07d62c6c4eb9d5b60e0754bdfe0412dd623bd8373dfa
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.14.0-py3-none-any.whl size=535289 sha256=9e4de13abec6fbac97d10717b48530501329c64d7668958412256f1937078bc2
#   Stored in directory: /root/.cache/pip/wheels/16/3c/68/b7eab618d9f1d5e7d386296f1e07e2cf36aaa1eb5161885038
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31407 sha256=8eb202ff7fd9f283a083dd20a164f8dd71279eb65039146c2802a7ec2a3b4a35
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built opendelta oss2 web.py aliyun-python-sdk-core crcmod
# Installing collected packages: sentencepiece, crcmod, yacs, smmap, pycryptodome, jmespath, jaraco.functools, gitdb, cheroot, web.py, gitpython, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, bigmodelvis, delta_center_client, opendelta
# Successfully installed aliyun-python-sdk-core-2.14.0 aliyun-python-sdk-kms-2.16.2 bigmodelvis-0.0.1 cheroot-10.0.0 crcmod-1.7 delta_center_client-0.0.4 gitdb-4.0.11 gitpython-3.1.40 jaraco.functools-4.0.0 jmespath-0.10.0 opendelta-0.3.2 oss2-2.15.0 pycryptodome-3.19.0 sentencepiece-0.1.99 smmap-5.0.1 web.py-0.62 yacs-0.1.8

# %% [markdown]
# Use `OpenDelta` library to do the same thing. [link](https://opendelta.readthedocs.io/en/latest/modules/deltas.html)
#
# For hyperparameters, test with `N_SOFT_PROMPT_TOKENS=1` and `N_SOFT_PROMPT_TOKENS=10` and report them in your report.

# %%
from opendelta import AutoDeltaConfig, AutoDeltaModel
from transformers import Trainer, TrainingArguments
from transformers import EvalPrediction
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/deepspeed.py:23: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(

# %%
model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)

######### Your code begins #########
####################################
####################################

N_SOFT_PROMPT_TOKENS=10

# Assume 'model' is your pre-trained model
delta_config = AutoDeltaConfig.from_dict({"delta_type": "soft_prompt", "soft_token_num": N_SOFT_PROMPT_TOKENS})
delta_model = AutoDeltaModel.from_config(delta_config, backbone_model=model)
delta_model.freeze_module(set_state_dict=True)


# Assume 'train_dataset' is your training dataset
training_args = TrainingArguments(
    './temp',
    learning_rate=LEARNING_RATE,
    num_train_epochs=EPOCHS,
    logging_strategy='epoch',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE
)

def compute_accuracy(p: EvalPrediction):
    labels_ids = p.label_ids
    pred_ids = p.predictions[0]

    #preds = np.argmax(p.predictions, axis=1)
    return {"acc": (labels_ids == pred_ids).mean()}


def preprocess_logits_for_metrics(logits, labels):
    """
    Original Trainer may have a memory leak.
    This is a workaround to avoid storing too many tensors that are not needed.
    """
    pred_ids = torch.argmax(logits[0], dim=-1)
    return pred_ids, labels

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=tokenizer,
    data_collator=col_fn,
    compute_metrics=compute_accuracy,#lambda p: {'acc': accuracy_score(p.label_ids, np.argmax(p.predictions, axis=1))}
    preprocess_logits_for_metrics=preprocess_logits_for_metrics
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# [WARNING|(OpenDelta)delta_configs:172]2023-11-13 05:03:50,942 >> The following keys are not used by <class 'opendelta.delta_models.soft_prompt.SoftPromptConfig'>.__init__ function: []
# [INFO|(OpenDelta)delta_configs:187]2023-11-13 05:03:50,949 >> Model config
# SoftPromptConfig {
#   "init_range": 0.5,
#   "opendelta_version": "0.3.0",
#   "soft_token_num": 10,
#   "token_init": true,
#   "transformers_version": "4.35.0"
# }

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='6948' max='7820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6948/7820 52:38 < 06:36, 2.20 it/s, Epoch 8.88/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.085700</td>
#       <td>0.179578</td>
#       <td>0.920360</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.220600</td>
#       <td>0.172635</td>
#       <td>0.924520</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.206200</td>
#       <td>0.171494</td>
#       <td>0.926760</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.200700</td>
#       <td>0.171162</td>
#       <td>0.928320</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.195100</td>
#       <td>0.170597</td>
#       <td>0.929800</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.193100</td>
#       <td>0.169670</td>
#       <td>0.930920</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.189300</td>
#       <td>0.167769</td>
#       <td>0.931180</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.187500</td>
#       <td>0.166002</td>
#       <td>0.931700</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='7820' max='7820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7820/7820 1:01:06, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.085700</td>
#       <td>0.179578</td>
#       <td>0.920360</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.220600</td>
#       <td>0.172635</td>
#       <td>0.924520</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.206200</td>
#       <td>0.171494</td>
#       <td>0.926760</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.200700</td>
#       <td>0.171162</td>
#       <td>0.928320</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.195100</td>
#       <td>0.170597</td>
#       <td>0.929800</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.193100</td>
#       <td>0.169670</td>
#       <td>0.930920</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.189300</td>
#       <td>0.167769</td>
#       <td>0.931180</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.187500</td>
#       <td>0.166002</td>
#       <td>0.931700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.185700</td>
#       <td>0.166542</td>
#       <td>0.931940</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.187200</td>
#       <td>0.166152</td>
#       <td>0.932120</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=7820, training_loss=0.3851190903607537, metrics={'train_runtime': 3667.1463, 'train_samples_per_second': 68.173, 'train_steps_per_second': 2.132, 'total_flos': 1.6919691264e+16, 'train_loss': 0.3851190903607537, 'epoch': 10.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='782' max='782' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [782/782 01:54]
#     </div>
# {'eval_loss': 0.16615204513072968,
#  'eval_acc': 0.93212,
#  'eval_runtime': 114.3032,
#  'eval_samples_per_second': 218.717,
#  'eval_steps_per_second': 6.841,
#  'epoch': 10.0}

# %%
model = T5ForConditionalGeneration.from_pretrained(BASE_MODEL_NAME)

######### Your code begins #########
####################################
####################################

from opendelta import AutoDeltaConfig, AutoDeltaModel
from transformers import Trainer, TrainingArguments
from transformers import EvalPrediction
from transformers import TrainingArguments, Trainer

N_SOFT_PROMPT_TOKENS=1

# Assume 'model' is your pre-trained model
delta_config = AutoDeltaConfig.from_dict({"delta_type": "soft_prompt", "soft_token_num": N_SOFT_PROMPT_TOKENS})
delta_model = AutoDeltaModel.from_config(delta_config, backbone_model=model)
delta_model.freeze_module(set_state_dict=True)


# Assume 'train_dataset' is your training dataset
training_args = TrainingArguments(
    './temp',
    learning_rate=LEARNING_RATE,
    num_train_epochs=EPOCHS,
    logging_strategy='epoch',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE
)

def compute_accuracy(p: EvalPrediction):
    labels_ids = p.label_ids
    pred_ids = p.predictions[0]

    #preds = np.argmax(p.predictions, axis=1)
    return {"acc": (labels_ids == pred_ids).mean()}


def preprocess_logits_for_metrics(logits, labels):
    """
    Original Trainer may have a memory leak.
    This is a workaround to avoid storing too many tensors that are not needed.
    """
    pred_ids = torch.argmax(logits[0], dim=-1)
    return pred_ids, labels

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=tokenizer,
    data_collator=col_fn,
    compute_metrics=compute_accuracy,#lambda p: {'acc': accuracy_score(p.label_ids, np.argmax(p.predictions, axis=1))}
    preprocess_logits_for_metrics=preprocess_logits_for_metrics
)
# Out:
# [WARNING|(OpenDelta)delta_configs:172]2023-11-13 05:04:03,326 >> The following keys are not used by <class 'opendelta.delta_models.soft_prompt.SoftPromptConfig'>.__init__ function: []
# [INFO|(OpenDelta)delta_configs:187]2023-11-13 05:04:03,330 >> Model config
# SoftPromptConfig {
#   "init_range": 0.5,
#   "opendelta_version": "0.3.0",
#   "soft_token_num": 1,
#   "token_init": true,
#   "transformers_version": "4.35.0"
# }

# %%
trainer.train()
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='7820' max='7820' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7820/7820 1:00:30, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Acc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>8.737300</td>
#       <td>0.283773</td>
#       <td>0.910760</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.603200</td>
#       <td>0.190761</td>
#       <td>0.919000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.340300</td>
#       <td>0.188528</td>
#       <td>0.919640</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.295900</td>
#       <td>0.185184</td>
#       <td>0.920420</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.277600</td>
#       <td>0.182269</td>
#       <td>0.921220</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.263400</td>
#       <td>0.179210</td>
#       <td>0.922240</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.254700</td>
#       <td>0.176797</td>
#       <td>0.923020</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.250100</td>
#       <td>0.175294</td>
#       <td>0.923300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.244400</td>
#       <td>0.174382</td>
#       <td>0.923700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.242200</td>
#       <td>0.174081</td>
#       <td>0.923820</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=7820, training_loss=1.1509112950785996, metrics={'train_runtime': 3633.2015, 'train_samples_per_second': 68.81, 'train_steps_per_second': 2.152, 'total_flos': 1.6917921792e+16, 'train_loss': 1.1509112950785996, 'epoch': 10.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='782' max='782' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [782/782 01:51]
#     </div>
# {'eval_loss': 0.1740807592868805,
#  'eval_acc': 0.92382,
#  'eval_runtime': 111.8608,
#  'eval_samples_per_second': 223.492,
#  'eval_steps_per_second': 6.991,
#  'epoch': 10.0}
